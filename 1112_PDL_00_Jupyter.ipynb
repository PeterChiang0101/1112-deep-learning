# %% [raw]
# Jake VanderPlas (2016). Python Data Science Handbook: Essential Tools for Working with Data. Chapter 1

# %% [raw]
# 鄧文淵 總監製/文淵閣工作室 編著(2021)。Python 自學聖經：從程式素人到開發強者的技術與實戰大全, 2/e。第一章

# %% [raw]
# 鄧文淵 總監製/文淵閣工作室 編著(2022)。Python 資料科學自學聖經：不只是建模！用實戰帶你預測趨勢、找出問題與發現價值。第一章

# %% [markdown]
# # IPython: Beyond Normal Python

# %% [markdown]
# IPython (http://ipython.org/) is closely tied with the Jupyter project (http://jupyter.org), which provides a browser-based notebook that is useful for development, collaboration, sharing, and even publication of data science results

# %% [markdown]
# Jupyter Notebook 是一個 IPython 的 Web 擴充模組，
# 讓使用者在瀏覽器中進行程式的開發與執行。

# %% [markdown]
# ## Launching the Jupyter Notebook

# %% [markdown]
# #### Windows 執行 Jupyter Notebook

# %% [markdown]
# * (Windows) 執行 開始 > 所有程式 > Anaconda (64-bit) > Jupyter Notebook; or
# * (Windows) Anaconda Prompt > Juputer Notebook; or
# * (Windows) Anaconda Navigator > Juputer Notebokk > Lauch

# %% [markdown]
# #### Mac 執行 Jupyter Notebook

# %% [markdown]
# * Terminal 終端機 > (env name) ...  ~% jupyter notebook; or
# * Anaconda-Navigator > Juputer Notebokk > Lauch

# %% [markdown]
# The Jupyter notbook is a browser-based graphical interface to the IPython shell, and builds on it a rich set of dynamic display capabilities.

# %% [markdown]
# Though the IPython notebook is viewed and edited through your web browser window, it must connect to a running Python process in order to execute code. To start this process (known as a "kernel"), running the following command in your system shell

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202023-02-17%20%E4%B8%8B%E5%8D%885.49.35.png](attachment:%E6%88%AA%E5%9C%96%202023-02-17%20%E4%B8%8B%E5%8D%885.49.35.png)

# %% [markdown]
# Upon issuing the command, your default browser should automatically open and navigate to the listed local URL; the exact address will depend on your system. If the brower does not open automatically, you can open a window and manually open this address (http://localhost:8888/ in this example)

# %% [markdown]
# 安裝時在本機建立的一個網頁伺服器，預設的路徑是 <c:\Users\帳號名稱> (Home目錄)，下方會列出預設路徑中所有的資料夾和檔案

# %% [markdown]
# #### Jupyter Notebook 執行程式

# %% [markdown]
# 完成 Cell 中的程式後，可以 1) 按工具列的Run按鈕 或 2) Shift + Enter 鍵執行程式，
# 結果會顯示在 Cell 下方並且新增一個 Cell。

# %% [markdown]
# ## Help and Documentation in Jupyter Notebook

# %% [markdown]
# Some examples of the questions IPython can help answer in a few keystrokes:

# %% [raw]
# How do I call this function? What arguments and options does it have?

# %% [raw]
# What does the source code of this IPython object look like?

# %% [raw]
# What is in this package I imported? What attributes or methods does this project have?

# %% [markdown]
# ## Accessing Documentation with ?

# %% [markdown]
# Every Python object contains the reference to a string, known as a docstring, which in most cases will contain a concise summary of the object and how to use it.

# %% [markdown]
# Python has a built-in help( ) function that can access this information and print the results.

# %%
# to see the documentation of the built-in len function
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# IPython introduces the ? character as a shorthand for accessing this documentation and other relevant information:

# %%
len?

# %% [markdown]
# This notation works for just about anything, including object methods

# %%
L = [1, 2, 3]

# %%
L.insert?

# %%
L?

# %% [markdown]
# This will even work for functions or other objects you create yourself.

# %% [markdown]
# To create a docstring for our functions, we simply placed a string literal in the first time. Because docstrings are usually multiple lines, by convetion we used Python's triple-quote notation for multiline strings.

# %%
def square(a):
    """Return the square of a."""
    return a**2

# %%
square?

# %% [markdown]
# ## Accessing Source Code with ??

# %% [markdown]
# IPython provides a shortcut to the source code with the double question mark (??)

# %%
square??

# %% [markdown]
# You'll notice that sometimes the ?? suffix doesn't display any source code: this is generally because the object in question is not implemented in Python, but in C or some other compiled extension language.

# %% [markdown]
# If this is the case, the ?? suffix gives the same output as the ? suffix.

# %%
len??

# %% [markdown]
# ## Exploring Modules with Tab Completion

# %% [raw]
# Tab completion of object contents

# %% [markdown]
# To see a list of all available attributes of an objects, you can type the name of the object followed by a period (.) character and the Tab key.

# %%
# L.<TAB>, L.c<TAB>, L.co<Tab>. L.cou<Tab>
#L.

# %% [raw]
# Tab completion when importing

# %% [markdown]
# Tab completion is also useful when importing objects from packages.

# %%
# from itertools import co<TAB> 
#from itertools import co

# %% [raw]
# Beyond tab completion: Wildcard matching

# %% [markdown]
# If you'd like to match characters at the middle of end of the word, IPython provides a means of wildcard matching for names using the * character

# %% [markdown]
# Note that the * character matches any string, including the empty string

# %%
# to list every object in the namespaces that ends with Warning
#*Warning?

# %%
# a string method that contains the word find somewhere in its name
#str.*find*?

# %% [markdown]
# ## Magic Commands (魔術指令 %) in Jupyter / Colab

# %% [markdown]
# Magic commands are prefixed by the % character

# %% [markdown]
# 1. 行魔術指令(Line Magic) 以「%」開頭，適用於單行命令
# 2. 儲存格魔術指令(Cell Magic) 以「%%」開頭，適用於多行命令

# %% [markdown]
# https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %% [raw]
# 「%lsmagic」顯示所有可用的魔術指令，可進行指令的查詢。

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [raw]
# Running External Code: %run

# %%
# file: myscript.py
# %run myscript.py
# Out:
# 1 square is 1
# 2 square is 4
# 3 square is 9

# %% [markdown]
# Note also that after you've run this script, any functions defined within it are available for use in your IPython session

# %%
square(5)
# Out:
# 25

# %% [raw]
# Time Code Execution: %timeit

# %% [markdown]
# %timeit, which will automatically determine the execution time of single-line Python statement that follows it.

# %%
# %timeit L=[n**2 for n in range(1000000)] # list comprehension
# Out:
# 212 ms ± 534 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# For multiline statements, adding a second % sign will turn this into a cell magic that can handle multiple lines of input.

# %%
# %%timeit 
L = []
for n in range(1000000):
    L.append(n **2)
# Out:
# 214 ms ± 360 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [raw]
# 「%whos」功能是查看目前存在的所有變數和類型等

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# L          list        n=3
# N          int         3
# square     function    <function square at 0x103b70670>

# %% [markdown]
# ## Input and Output History

# %% [raw]
# IPython's In and Out Objects

# %% [markdown]
# IPython actually creates some Python variables called In and Out that are automatically updated to reflect this history

# %%
import math

# %%
math.sin(2)
# Out:
# 0.9092974268256817

# %%
math.cos(2)
# Out:
# -0.4161468365471424

# %%
print(In) # data strcture is list
# Out:
# ['', '# to see the documentation of the built-in len function\nhelp(len)', "get_ipython().run_line_magic('pinfo', 'len')", 'L = [1, 2, 3]', "get_ipython().run_line_magic('pinfo', 'L.insert')", "get_ipython().run_line_magic('pinfo', 'L')", 'def square(a):\n    """Return the square of a."""\n    return a**2', "get_ipython().run_line_magic('pinfo', 'square')", "get_ipython().run_line_magic('pinfo2', 'square')", "get_ipython().run_line_magic('pinfo2', 'len')", '# L.<TAB>, L.c<TAB>, L.co<Tab>. L.cou<Tab>\n# L.', '# from itertools import co<TAB> \n# from itertools import co', '# to list every object in the namespaces that ends with Warning\n#*Warning?', '# a string method that contains the word find somewhere in its name\n#str.*find*?', "get_ipython().run_line_magic('lsmagic', '')", "# file: myscript.py\nget_ipython().run_line_magic('run', 'myscript.py')", 'square(5)', "get_ipython().run_line_magic('timeit', 'L=[n**2 for n in range(1000000)] # list comprehension')", "get_ipython().run_cell_magic('timeit', '', 'L = []\\nfor n in range(1000000):\\n    L.append(n **2)\\n')", "get_ipython().run_line_magic('whos', '')", 'import math', 'math.sin(2)', 'math.cos(2)', 'print(In) # data strcture is list ']

# %%
Out # data structue is dictionary
# Out:
# {14: Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#  16: 25,
#  21: 0.9092974268256817,
#  22: -0.4161468365471424}

# %% [raw]
# Underscore Shortcuts and Previous Outputs

# %% [markdown]
# The standard Python shell contains just one simple shortcut for accessing the previous output; the variable _ (i.e., a single underscore) is kept updated with the previous output; this works in IPython as well.

# %%
print(_)
# Out:
# -0.4161468365471424

# %% [markdown]
# But IPython takes this a bit further -- you can use a double underscore to access the second-to-last output, and a triple undersocee to access the third-to-last output

# %%
print(__)
# Out:
# 0.9092974268256817

# %%
print(___)
# Out:
# 25

# %% [raw]
# Suppressing Output

# %% [markdown]
# Sometimes you might wish to suppress the output of a statement. The easiest way to suppress the output of a command is to add a semicolon(;) to the end of the line

# %%
math.sin(2) + math.cos(2);

# %% [markdown]
# ## Shell Commands in Jupyter / Colab

# %% [markdown]
# You can use any command that works at the command line in IPython by prefixing it with the ! character

# %% [markdown]
# 允許使用者執行 shell命令與系統互動，格式為 ！shell指令

# %%
# !ls
# Out:
# 1112_PDL_00_Jupyter.ipynb          1112_PDL_CourseOverview.key
# 1112_PDL_01_DataTypes.ipynb        1112_PDL_CourseOverview.pdf
# 1112_PDL_02_Numbers.ipynb          Anaconda3-2022.10-MacOSX-arm64.pkg
# 1112_PDL_03_TextStrings.ipynb      HW
# 1112_PDL_04_ChooseWithIF.ipynb     myscript.py
# 1112_PDL_05_LoopWithWhileFor.ipynb tensorflow_env.ipynb
# 1112_PDL_CNN_Cifar10.ipynb         test.ipynb

# %%
# !pwd
# Out:
# /Users/lunghao/Documents/NCU/Course/PDL/1112

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.1
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# astroid                       2.11.7
# astropy                       5.1
# asttokens                     2.0.5
# attrs                         21.4.0
# Automat                       20.2.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# bitarray                      2.5.1
# bkcharts                      0.2
# bleach                        4.1.0
# bokeh                         2.4.3
# boto3                         1.24.28
# botocore                      1.27.28
# Bottleneck                    1.3.5
# brotlipy                      0.7.0
# certifi                       2022.9.24
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.5
# colorcet                      3.0.0
# conda                         22.9.0
# conda-build                   3.22.0
# conda-content-trust           0.1.3
# conda-pack                    0.6.0
# conda-package-handling        1.9.0
# conda-repo-cli                1.0.20
# conda-token                   0.4.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cryptography                  37.0.1
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.32
# cytoolz                       0.11.0
# dask                          2022.7.0
# datashader                    0.14.1
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# dill                          0.3.4
# distributed                   2022.7.0
# docutils                      0.18.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.16.2
# filelock                      3.6.0
# Flask                         1.1.2
# fonttools                     4.25.0
# fsspec                        2022.7.1
# future                        0.18.2
# gensim                        4.1.2
# glob2                         0.7
# gmpy2                         2.1.2
# greenlet                      1.1.0
# h5py                          3.7.0
# HeapDict                      1.0.1
# holoviews                     1.15.0
# hvplot                        0.8.0
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# imageio                       2.19.3
# imagesize                     1.4.1
# importlib-metadata            4.11.3
# incremental                   21.3.0
# iniconfig                     1.1.1
# intake                        0.6.5
# ipykernel                     6.15.2
# ipython                       8.4.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jdcal                         1.4.1
# jedi                          0.18.1
# Jinja2                        2.11.3
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.16.0
# jupyter_client                7.3.4
# jupyter-console               6.4.3
# jupyter_core                  4.11.1
# jupyter-server                1.18.1
# jupyterlab                    3.4.4
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# kiwisolver                    1.4.2
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# llvmlite                      0.38.0
# locket                        1.0.0
# lxml                          4.9.1
# lz4                           3.1.3
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.5.2
# matplotlib-inline             0.1.6
# mccabe                        0.7.0
# mistune                       0.8.4
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.3
# multipledispatch              0.6.0
# munkres                       1.1.4
# navigator-updater             0.3.0
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.5.0
# nest-asyncio                  1.5.5
# networkx                      2.8.4
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.12
# numba                         0.55.1
# numexpr                       2.8.3
# numpy                         1.21.5
# numpydoc                      1.4.0
# olefile                       0.46
# openpyxl                      3.0.10
# packaging                     21.3
# pandas                        1.4.4
# pandocfilters                 1.5.0
# panel                         0.13.1
# param                         1.12.0
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathlib                       1.0.1
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           22.2.2
# pkginfo                       1.8.2
# platformdirs                  2.5.2
# plotly                        5.9.0
# pluggy                        1.0.0
# ply                           3.11
# prometheus-client             0.14.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# psutil                        5.9.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.8.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.8
# pycurl                        7.45.1
# PyDispatcher                  2.0.5
# pyerfa                        2.0.0
# pyflakes                      2.4.0
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.4.0
# pylint                        2.14.5
# pyodbc                        4.0.34
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.9
# PyQt5-sip                     12.11.0
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.2
# python-dateutil               2.8.2
# python-snappy                 0.6.0
# pytz                          2022.1
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# PyYAML                        6.0
# pyzmq                         23.2.0
# QtPy                          2.2.0
# queuelib                      1.5.0
# regex                         2022.7.9
# requests                      2.28.1
# requests-file                 1.5.1
# rope                          0.22.0
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.6.0
# scikit-image                  0.19.2
# scikit-learn                  1.1.1
# scipy                         1.9.1
# Scrapy                        2.6.2
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    63.4.1
# sip                           6.6.2
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# SQLAlchemy                    1.4.39
# stack-data                    0.2.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.7.0
# tabulate                      0.8.10
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# terminado                     0.13.1
# testpath                      0.6.0
# threadpoolctl                 2.2.0
# tifffile                      2021.7.2
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.1
# toolz                         0.11.2
# tornado                       6.1
# tqdm                          4.64.1
# traitlets                     5.1.1
# Twisted                       22.2.0
# typing_extensions             4.3.0
# ujson                         5.4.0
# urllib3                       1.26.11
# w3lib                         1.21.0
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# wrapt                         1.14.1
# xarray                        0.20.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.27.15
# zict                          2.1.0
# zipp                          3.8.0
# zope.interface                5.4.0

# %% [markdown]
# #### 常見的 shell 指令

# %% [markdown]
# + ls [-l] ==> 顯示檔案或目錄內容結構 -l: 詳細檔案內容結構
# + pwd ==> 顯示當前目錄
# + cat [-n] 檔名 ==> 顯示檔案內容 -n: 顯示行號
# + mkdir 目錄名稱 ==> 建立新目錄
# + rmdir 目錄名稱 ==> 移除目錄，目錄必須是空的
# + rm [-i] [-rf] 檔案或目錄名稱 ==> 移除 檔案或目錄。-i: 移除前需確認 -rf: 刪除目錄不必是空的
# + mv 檔案或目錄名稱 目的目錄 ==> 移動 檔案或目錄到目的目錄
# + cp [-r] 檔案或目錄名稱 目的目錄 ==> 複製 檔案或目錄到目的目錄。-r: 複製目錄
# + ln -s 目錄名稱 虛擬目錄名稱 ==> 將目錄名稱設為虛擬名稱。常用於簡化 Google雲端硬碟
# 目錄
# + unzip 壓縮檔名 ==> 將壓縮檔解壓縮
# + sed -i 's/搜尋字串/取代字串/g' ==> 將檔案中所有「搜尋字串」取代為「取代字串」
# + wget [-o 自訂檔名] 遠端檔案網址 ==> 下載遠端檔案回到本機。 -o: 可自訂檔名

# %% [markdown]
# ## Markdown 語法

# %% [markdown]
# Markdown 是一種輕量級標記語言，有純文字的特性，可提高編寫的可讀性。

# %% [markdown]
# Markdown 顯示結構可區分為兩大類：
# 1. 區塊元素：此類別讓內容獨立成一個區塊，區塊內的全部文字都是套用同樣的格式。
# 2. 行內元素：套用此類別的內容可插入於區塊內。

# %% [markdown]
# ### 區塊元素

# %% [raw]
# 標題文字：分為六個層級，在標題文字前方加上1到6個「#」符號，「#」數量越少則標題文字越大

# %% [markdown]
# # 標題1
# ## 標題2
# ### 標題3
# #### 標題4
# ##### 標題5
# ###### 標題6

# %% [raw]
# 段落文字：當沒有加上任何符號時，該區塊的文字就是文字段落區塊，段落與段落間以空白列隔開。

# %% [markdown]
#   這是段落文字一
#
#   這是段落文字二

# %% [raw]
# 引用文字：在文字前方加上「>」符號，類似於Email回覆時原文呈現的樣式

# %% [markdown]
# >這是引用文字

# %% [raw]
# 項目符號清單：在文字前方加上「-」或「+」或「*」符號及一個空白字元，功能是建立清單項目

# %% [markdown]
# * item1
# * item2
# * item3

# %% [markdown]
# + item1
# + item2
# + item3

# %% [markdown]
# - item1
#   - item11
# - item2
#   + item21
#     * item211
# - item3

# %% [raw]
# 編號清單：以數字加上「.」及一個空白字元作為開頭的文字，功能是建立包含數字編號的清單項目

# %% [markdown]
# 1. item1
# 2. item2
# 3. item3

# %% [raw]
# 分隔線：連續3個 * 或 - 符號建立一條橫線以分隔文字

# %% [markdown]
# ***

# %% [markdown]
# ---

# %% [raw]
# 區塊程式碼：Markdown說明中需要顯示程式碼，其語法為：

# %% [markdown]
# ```
#   程式碼
#   for x in range(5):
#       print(x)
# ```

# %% [markdown]
# ### 行內元素

# %% [raw]
# 斜體文字：若文字被 _ 或 * 符號包圍，該文字就會以斜體文字顯示

# %% [markdown]
# _斜體文字1_

# %% [markdown]
# *斜體文字2*

# %% [raw]
# 粗體文字：若文字被 __ 或 ** 符號包圍，該文字就會以粗體文字顯示

# %% [markdown]
# __粗體文字1__

# %% [markdown]
# **粗體文字2**

# %% [raw]
# 超連結：[顯示文字](網址)

# %% [markdown]
# [國立中央大學](https://www.ncu.edu.tw/)

# %% [raw]
# 圖片：！[替代文字](圖片網址)

# %% [markdown]
# ![NCU Logo](https://www.ncu.edu.tw/upload/ckupload/img/20210607_03115877.png)

# %% [markdown]
# ![w1200.jpeg](attachment:w1200.jpeg)
